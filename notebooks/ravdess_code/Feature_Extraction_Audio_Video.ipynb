# %%
# !nvidia-smi -L
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# 2024-07-07 12:04:07.175858: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ''

# %%
#!pip uninstall tensorflow-data-validation

# %%
#Kill all the processes at beginning of a runtime
import os
os.kill(os.getpid(), 9)

# %%
#imports
import numpy as np
import random as rd
import pandas as pd
import tensorflow as tf
from IPython.display import Video,Audio
import dlib
import cv2
from tqdm import tqdm
from tqdm.notebook import tqdm_notebook
import pickle
import librosa
import librosa.display
tf.test.gpu_device_name()
#print("Done")
# Out:
# 2024-07-26 21:32:53.794141: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ''

# %%
seed_constant = 27
np.random.seed(seed_constant)
rd.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %%
dir = '/var/scratch/mpa326/'
video_folder = '/var/scratch/mpa326/Ravdess_dataset/Video_Speech'
audio_folder = '/var/scratch/mpa326/Ravdess_dataset/Audio_Speech'

# %%
getdf=f'{dir}/recognition_of_emotions_from_videos'

# %%
import sys
sys.path.append(getdf)

# %%
import getData 
df_video=getData.getdata(video_folder)
df_video.head()
# Out:
#                                           Audio_file    modality  \
# 0  /var/scratch/mpa326/Ravdess_dataset/Video_Spee...  video-only
# 1  /var/scratch/mpa326/Ravdess_dataset/Video_Spee...  video-only
# 2  /var/scratch/mpa326/Ravdess_dataset/Video_Spee...  video-only
# 3  /var/scratch/mpa326/Ravdess_dataset/Video_Spee...  video-only
# 4  /var/scratch/mpa326/Ravdess_dataset/Video_Spee...  video-only
#
#   vocal_channel  emotion emotional_intensity                     statement  \
# 0        speech  neutral              normal  Kids are talking by the door
# 1        speech  neutral              normal  Kids are talking by the door
# 2        speech  neutral              normal  Dogs are sitting by the door
# 3        speech  neutral              normal  Dogs are sitting by the door
# 4        speech     calm              normal  Kids are talking by the door
#
#        repetition  gender
# 0  1st repetition  female
# 1  2nd repetition  female
# 2  1st repetition  female
# 3  2nd repetition  female
# 4  1st repetition  female

# %%
df_video['gender']
# Out:
# 0       female
# 1       female
# 2       female
# 3       female
# 4       female
#          ...
# 1435      male
# 1436      male
# 1437      male
# 1438      male
# 1439      male
# Name: gender, Length: 1440, dtype: object

# %%
df_video_only=df_video[df_video.modality=='video-only']

# %%
df_video_only['gender'].value_counts()
# Out:
# gender
# female    720
# male      720
# Name: count, dtype: int64

# %%
df_video_only['emotion'].value_counts()
# Out:
# emotion
# calm         192
# happy        192
# sad          192
# angry        192
# fearful      192
# disgust      192
# surprised    192
# neutral       96
# Name: count, dtype: int64

# %%
 df_video_only.groupby(['emotion', 'gender']).size().unstack()
# Out:
# gender     female  male
# emotion
# angry          96    96
# calm           96    96
# disgust        96    96
# fearful        96    96
# happy          96    96
# neutral        48    48
# sad            96    96
# surprised      96    96

# %%
#!pip install get-video-properties

# %%
from videoprops import get_video_properties

def video_properties(lien:str) ->  dict:
  props = get_video_properties(lien)
  props_=dict()
  info=['codec_name','width','height','avg_frame_rate','display_aspect_ratio','nb_frames']
  for i in info:
    if i in ['width','height','nb_frames']:
      props_[i]=int(props[i])
    else:
      props_[i]=props[i]
  props_['duration']=float(props['duration'])
  props_['fps']=int(int(props['nb_frames'])//float(props['duration']))
  props_['dir']=lien
  
  return props_

# %%
video_properties('/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_01/02-01-01-01-01-02-01.mp4')
# Out:
# {'codec_name': 'h264',
#  'width': 1280,
#  'height': 720,
#  'avg_frame_rate': '30000/1001',
#  'display_aspect_ratio': '16:9',
#  'nb_frames': 100,
#  'duration': 3.336667,
#  'fps': 29,
#  'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_01/02-01-01-01-01-02-01.mp4'}

# %%
f=list(df_video_only.Audio_file)

# %%
print(f)
# Out:
# ['/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-01-01-01-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-01-01-01-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-01-01-02-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-01-01-02-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-01-01-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-01-01-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-01-02-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-01-02-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-02-01-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-02-01-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-02-02-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-02-02-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-03-01-01-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-03-01-01-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-03-01-02-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-03-01-02-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-03-02-01-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-03-02-01-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-03-02-02-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-03-02-02-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-04-01-01-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-04-01-01-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-04-01-02-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-04-01-02-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-04-02-01-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-04-02-01-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-04-02-02-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-04-02-02-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-05-01-01-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-05-01-01-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-05-01-02-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-05-01-02-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-05-02-01-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-05-02-01-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-05-02-02-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-05-02-02-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-06-01-01-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-06-01-01-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-06-01-02-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-06-01-02-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-06-02-01-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-06-02-01-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-06-02-02-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-06-02-02-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-07-01-01-01-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-07-01-01-02-14.mp4', '/var/scratch/mpa326/Ravdess_dataset/Video_ ...

# %%
df_video_properties=map(video_properties,f[:1440])

# %%
print(df_video_properties)
# Out:
# <map object at 0x2aac57fc3d30>

# %%
df_video_properties=list(df_video_properties)

# %%
print(df_video_properties)
# Out:
# [{'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1001', 'display_aspect_ratio': '16:9', 'nb_frames': 104, 'duration': 3.470133, 'fps': 29, 'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-01-01-01-01-14.mp4'}, {'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1001', 'display_aspect_ratio': '16:9', 'nb_frames': 100, 'duration': 3.336667, 'fps': 29, 'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-01-01-01-02-14.mp4'}, {'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1001', 'display_aspect_ratio': '16:9', 'nb_frames': 104, 'duration': 3.470133, 'fps': 29, 'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-01-01-02-01-14.mp4'}, {'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1001', 'display_aspect_ratio': '16:9', 'nb_frames': 107, 'duration': 3.570233, 'fps': 29, 'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-01-01-02-02-14.mp4'}, {'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1001', 'display_aspect_ratio': '16:9', 'nb_frames': 112, 'duration': 3.737067, 'fps': 29, 'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-01-01-01-14.mp4'}, {'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1001', 'display_aspect_ratio': '16:9', 'nb_frames': 107, 'duration': 3.570233, 'fps': 29, 'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-01-01-02-14.mp4'}, {'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1001', 'display_aspect_ratio': '16:9', 'nb_frames': 102, 'duration': 3.4034, 'fps': 29, 'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-01-02-01-14.mp4'}, {'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1001', 'display_aspect_ratio': '16:9', 'nb_frames': 105, 'duration': 3.5035, 'fps': 29, 'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-01-02-02-14.mp4'}, {'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1001', 'display_aspect_ratio': '16:9', 'nb_frames': 116, 'duration': 3.870533, 'fps': 29, 'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-02-01-01-14.mp4'}, {'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1001', 'display_aspect_ratio': '16:9', 'nb_frames': 117, 'duration': 3.9039, 'fps': 29, 'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-02-01-02-14.mp4'}, {'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1001', 'display_aspect_ratio': '16:9', 'nb_frames': 112, 'duration': 3.737067, 'fps': 29, 'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-02-02-01-14.mp4'}, {'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1001', 'display_aspect_ratio': '16:9', 'nb_frames': 113, 'duration': 3.770433, 'fps': 29, 'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-02-02-02-02-14.mp4'}, {'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1001', 'display_aspect_ratio': '16:9', 'nb_frames': 111, 'duration': 3.7037, 'fps': 29, 'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-03-01-01-01-14.mp4'}, {'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1001', 'display_aspect_ratio': '16:9', 'nb_frames': 110, 'duration': 3.670333, 'fps': 29, 'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-03-01-01-02-14.mp4'}, {'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1001', 'display_aspect_ratio': '16:9', 'nb_frames': 102, 'duration': 3.4034, 'fps': 29, 'dir': '/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_14/02-01-03-01-02-01-14.mp4'}, {'codec_name': 'h264', 'width': 1280, 'height': 720, 'avg_frame_rate': '30000/1 ...

# %%
df=pd.DataFrame(df_video_properties)
df.head()
# Out:
#   codec_name  width  height avg_frame_rate display_aspect_ratio  nb_frames  \
# 0       h264   1280     720     30000/1001                 16:9        104
# 1       h264   1280     720     30000/1001                 16:9        100
# 2       h264   1280     720     30000/1001                 16:9        104
# 3       h264   1280     720     30000/1001                 16:9        107
# 4       h264   1280     720     30000/1001                 16:9        112
#
#    duration  fps                                                dir
# 0  3.470133   29  /var/scratch/mpa326/Ravdess_dataset/Video_Spee...
# 1  3.336667   29  /var/scratch/mpa326/Ravdess_dataset/Video_Spee...
# 2  3.470133   29  /var/scratch/mpa326/Ravdess_dataset/Video_Spee...
# 3  3.570233   29  /var/scratch/mpa326/Ravdess_dataset/Video_Spee...
# 4  3.737067   29  /var/scratch/mpa326/Ravdess_dataset/Video_Spee...

# %%
df.insert(1,"emotion",list(df_video_only.emotion))
df.insert(1,"gender",list(df_video_only.gender))

# %%
print(df)
# Out:
#      codec_name  gender    emotion  width  height avg_frame_rate  \
# 0          h264  female    neutral   1280     720     30000/1001
# 1          h264  female    neutral   1280     720     30000/1001
# 2          h264  female    neutral   1280     720     30000/1001
# 3          h264  female    neutral   1280     720     30000/1001
# 4          h264  female       calm   1280     720     30000/1001
# ...         ...     ...        ...    ...     ...            ...
# 1435       h264    male  surprised   1280     720     30000/1001
# 1436       h264    male  surprised   1280     720     30000/1001
# 1437       h264    male  surprised   1280     720     30000/1001
# 1438       h264    male  surprised   1280     720     30000/1001
# 1439       h264    male  surprised   1280     720     30000/1001
#
#      display_aspect_ratio  nb_frames  duration  fps  \
# 0                    16:9        104  3.470133   29
# 1                    16:9        100  3.336667   29
# 2                    16:9        104  3.470133   29
# 3                    16:9        107  3.570233   29
# 4                    16:9        112  3.737067   29
# ...                   ...        ...       ...  ...
# 1435                 16:9         98  3.269933   29
# 1436                 16:9        103  3.436767   29
# 1437                 16:9        107  3.570233   29
# 1438                 16:9        105  3.503500   29
# 1439                 16:9         98  3.269933   29
#
#                                                     dir
# 0     /var/scratch/mpa326/Ravdess_dataset/Video_Spee...
# 1     /var/scratch/mpa326/Ravdess_dataset/Video_Spee...
# 2     /var/scratch/mpa326/Ravdess_dataset/Video_Spee...
# 3     /var/scratch/mpa326/Ravdess_dataset/Video_Spee...
# 4     /var/scratch/mpa326/Ravdess_dataset/Video_Spee...
# ...                                                 ...
# 1435  /var/scratch/mpa326/Ravdess_dataset/Video_Spee...
# 1436  /var/scratch/mpa326/Ravdess_dataset/Video_Spee...
# 1437  /var/scratch/mpa326/Ravdess_dataset/Video_Spee...
# 1438  /var/scratch/mpa326/Ravdess_dataset/Video_Spee...
# 1439  /var/scratch/mpa326/Ravdess_dataset/Video_Spee...
#
# [1440 rows x 11 columns]

# %%
from IPython.display import HTML
from base64 import b64encode
 
def show_video(video_path, video_width = 300):
   
  video_file = open(video_path, "rb").read()
 
  video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
  return HTML(f"""""")

# %%
from sklearn.model_selection import train_test_split

# %%
emotion_labels = df['emotion']
genders = df['gender']

# %%
# def gender_split_train_test(df, emotion_labels, genders, gender_split=0.5):
#     # Verify the gender_split is between 0 and 1
#     if not 0 <= gender_split <= 1:
#         raise ValueError("gender_split should be between 0 and 1")

#     # Combine emotion labels and genders for stratification
#     combined_labels = [(e, g) for e, g in zip(emotion_labels, genders)]

#     # Create DataFrames for males and females
#     df_male = df[df['gender'] == 'male']
#     df_female = df[df['gender'] == 'female']
    
#     emotion_labels_male = [e for e, g in zip(emotion_labels, genders) if g == 'male']
#     emotion_labels_female = [e for e, g in zip(emotion_labels, genders) if g == 'female']
    
#     # Calculate the number of males and females required in the training set
#     total_train_size = int(0.8 * len(df))
#     n_males = int(gender_split * total_train_size)
#     n_females = total_train_size - n_males

#     # Ensure there are enough samples to meet the required split
#     if len(df_male) < n_males or len(df_female) < n_females:
#         raise ValueError("Not enough samples to meet the desired gender split")

#     # Split the DataFrames according to gender split
#     df_male_train, df_male_test, emotion_labels_male_train, emotion_labels_male_test = train_test_split(
#         df_male, emotion_labels_male, train_size=n_males, stratify=emotion_labels_male, random_state=42
#     )
    
#     df_female_train, df_female_test, emotion_labels_female_train, emotion_labels_female_test = train_test_split(
#         df_female, emotion_labels_female, train_size=n_females, stratify=emotion_labels_female, random_state=42
#     )
    
#     # Concatenate male and female DataFrames for train and test sets
#     X_train = pd.concat([df_male_train, df_female_train]).reset_index(drop=True)
#     X_test = pd.concat([df_male_test, df_female_test]).reset_index(drop=True)
    
#     y_train = emotion_labels_male_train + emotion_labels_female_train
#     y_test = emotion_labels_male_test + emotion_labels_female_test
    
#     gender_train = ['male'] * len(df_male_train) + ['female'] * len(df_female_train)
#     gender_test = ['male'] * len(df_male_test) + ['female'] * len(df_female_test)

#     # Return the final splits
#     return X_train, X_test, y_train, y_test, gender_train, gender_test

# %%
X_train, X_test, y_train, y_test, gender_train, gender_test = gender_split_train_test(
    df, emotion_labels, genders, gender_split=0.4
)

# %%
X_test['gender'].value_counts()
# Out:
# gender
# male      260
# female     28
# Name: count, dtype: int64

# %%
combined_labels = [(e, g) for e, g in zip(emotion_labels, genders)]
X_train, X_test, y_train, y_test, gender_train, gender_test = train_test_split(
    df, emotion_labels, genders, test_size=0.2, stratify=combined_labels, random_state=42
)

print("Train set shape:", X_train.shape)
#print("Validation set shape:", X_val.shape)
print("Test set shape:", X_test.shape)

print("Label Train set shape:", y_train.shape)
#print("Label Validation set shape:", y_val.shape)
print("Label Test set shape:", y_test.shape)

print("GenderTrain set shape:", gender_train.shape)
#print("Gender Validation set shape:", gender_val.shape)
print("Gender Test set shape:", gender_test.shape)
# Out:
# Train set shape: (1152, 11)
# Test set shape: (288, 11)
# Label Train set shape: (1152,)
# Label Test set shape: (288,)
# GenderTrain set shape: (1152,)
# Gender Test set shape: (288,)

# %%
X_train.groupby(['emotion', 'gender']).size().unstack()
# Out:
# gender     female  male
# emotion
# angry          77    77
# calm           77    76
# disgust        77    77
# fearful        76    77
# happy          77    77
# neutral        38    38
# sad            77    77
# surprised      77    77

# %%
X_test.groupby(['emotion', 'gender']).size().unstack()
# Out:
# gender     female  male
# emotion
# angry          19    19
# calm           19    20
# disgust        19    19
# fearful        20    19
# happy          19    19
# neutral        10    10
# sad            19    19
# surprised      19    19

# %%
target_male_count = 384
target_female_count = 576

# Separate neutral and non-neutral emotions
neutral_data = X_train[X_train['emotion'] == 'neutral']
non_neutral_data = X_train[X_train['emotion'] != 'neutral']
print("NON",non_neutral_data['emotion'].value_counts())

# Separate neutral data by gender
neutral_males = neutral_data[neutral_data['gender'] == 'male']
neutral_females = neutral_data[neutral_data['gender'] == 'female']

# Count males and females in neutral data
neutral_male_count = len(neutral_males)
neutral_female_count = len(neutral_females)

# Separate non-neutral data by gender
non_neutral_males = non_neutral_data[non_neutral_data['gender'] == 'male']
non_neutral_females = non_neutral_data[non_neutral_data['gender'] == 'female']

# Calculate the current counts
current_male_count = len(non_neutral_males)
current_female_count = len(non_neutral_females)

# Calculate the number to drop for each gender
excess_male = max(0, current_male_count - target_male_count + neutral_male_count)
excess_female = max(0, current_female_count - target_female_count + neutral_female_count)

# Calculate how much excess data to drop equally from each emotion
emotion_counts = non_neutral_data['emotion'].value_counts()
emotions = emotion_counts.index

# Determine the number to drop from each emotion for both males and females
drop_per_emotion_male = excess_male / len(emotions) if excess_male > 0 else 0
drop_per_emotion_female = excess_female / len(emotions) if excess_female > 0 else 0

# Drop excess data equally across each emotion
def drop_excess(data, drop_per_emotion):
    # Initialize an empty DataFrame to store the result
    reduced_data = pd.DataFrame()
    for emotion in emotions:
        emotion_data = data[data['emotion'] == emotion]
        if drop_per_emotion > 0:
            # Drop excess samples from the emotion data
            if len(emotion_data) > drop_per_emotion:
                sampled_data = emotion_data.sample(n=len(emotion_data) - int(drop_per_emotion), random_state=42)
            else:
                sampled_data = emotion_data
        else:
            sampled_data = emotion_data
        reduced_data = pd.concat([reduced_data, sampled_data])
    return reduced_data

# Apply the dropping function
reduced_males = drop_excess(non_neutral_males, drop_per_emotion_male)
reduced_females = drop_excess(non_neutral_females, drop_per_emotion_female)

# Combine neutral data with the reduced non-neutral data
X_train_40m_60f = pd.concat([neutral_data, reduced_males, reduced_females])

# Ensure we reach the exact size of target counts
X_train_40m_60f = X_train_40m_60f.groupby('gender').apply(lambda x: x.sample(n=target_male_count if x['gender'].iloc[0] == 'male' else target_female_count, random_state=42)).reset_index(drop=True)

# Check the final shape and balance
print(X_train_40m_60f.shape)  # Should be (960, 11)
print(X_train_40m_60f['emotion'].value_counts())  # Check distribution of emotions
print(X_train_40m_60f['gender'].value_counts())   # Should be 480 males and 480 females

X_train_40m_60f.groupby(['emotion', 'gender']).size().unstack()
# Out:
# NON emotion
# happy        154
# angry        154
# disgust      154
# surprised    154
# sad          154
# calm         153
# fearful      153
# Name: count, dtype: int64
# (960, 11)
# emotion
# disgust      127
# happy        127
# surprised    127
# angry        126
# sad          126
# calm         126
# fearful      125
# neutral       76
# Name: count, dtype: int64
# gender
# female    576
# male      384
# Name: count, dtype: int64
# /tmp/ipykernel_18171/3209840511.py:62: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   X_train_40m_60f = X_train_40m_60f.groupby('gender').apply(lambda x: x.sample(n=target_male_count if x['gender'].iloc[0] == 'male' else target_female_count, random_state=42)).reset_index(drop=True)
# gender     female  male
# emotion
# angry          77    49
# calm           77    49
# disgust        77    50
# fearful        76    49
# happy          77    50
# neutral        38    38
# sad            77    49
# surprised      77    50

# %%
target_male_count = 576
target_female_count = 384

# Separate neutral and non-neutral emotions
neutral_data = X_train[X_train['emotion'] == 'neutral']
non_neutral_data = X_train[X_train['emotion'] != 'neutral']
print("NON",non_neutral_data['emotion'].value_counts())

# Separate neutral data by gender
neutral_males = neutral_data[neutral_data['gender'] == 'male']
neutral_females = neutral_data[neutral_data['gender'] == 'female']

# Count males and females in neutral data
neutral_male_count = len(neutral_males)
neutral_female_count = len(neutral_females)

# Separate non-neutral data by gender
non_neutral_males = non_neutral_data[non_neutral_data['gender'] == 'male']
non_neutral_females = non_neutral_data[non_neutral_data['gender'] == 'female']

# Calculate the current counts
current_male_count = len(non_neutral_males)
current_female_count = len(non_neutral_females)

# Calculate the number to drop for each gender
excess_male = max(0, current_male_count - target_male_count + neutral_male_count)
excess_female = max(0, current_female_count - target_female_count + neutral_female_count)

# Calculate how much excess data to drop equally from each emotion
emotion_counts = non_neutral_data['emotion'].value_counts()
emotions = emotion_counts.index

# Determine the number to drop from each emotion for both males and females
drop_per_emotion_male = excess_male / len(emotions) if excess_male > 0 else 0
drop_per_emotion_female = excess_female / len(emotions) if excess_female > 0 else 0

# Drop excess data equally across each emotion
def drop_excess(data, drop_per_emotion):
    # Initialize an empty DataFrame to store the result
    reduced_data = pd.DataFrame()
    for emotion in emotions:
        emotion_data = data[data['emotion'] == emotion]
        if drop_per_emotion > 0:
            # Drop excess samples from the emotion data
            if len(emotion_data) > drop_per_emotion:
                sampled_data = emotion_data.sample(n=len(emotion_data) - int(drop_per_emotion), random_state=42)
            else:
                sampled_data = emotion_data
        else:
            sampled_data = emotion_data
        reduced_data = pd.concat([reduced_data, sampled_data])
    return reduced_data

# Apply the dropping function
reduced_males = drop_excess(non_neutral_males, drop_per_emotion_male)
reduced_females = drop_excess(non_neutral_females, drop_per_emotion_female)

# Combine neutral data with the reduced non-neutral data
X_train_60m_40f = pd.concat([neutral_data, reduced_males, reduced_females])

# Ensure we reach the exact size of target counts
X_train_60m_40f = X_train_60m_40f.groupby('gender').apply(lambda x: x.sample(n=target_male_count if x['gender'].iloc[0] == 'male' else target_female_count, random_state=42)).reset_index(drop=True)

# Check the final shape and balance
print(X_train_60m_40f.shape)  # Should be (960, 11)
print(X_train_60m_40f['emotion'].value_counts())  # Check distribution of emotions
print(X_train_60m_40f['gender'].value_counts())   # Should be 480 males and 480 females

X_train_60m_40f.groupby(['emotion', 'gender']).size().unstack()
# Out:
# NON emotion
# happy        154
# angry        154
# disgust      154
# surprised    154
# sad          154
# calm         153
# fearful      153
# Name: count, dtype: int64
# (960, 11)
# emotion
# disgust      127
# surprised    127
# happy        127
# calm         126
# angry        126
# sad          126
# fearful      125
# neutral       76
# Name: count, dtype: int64
# gender
# male      576
# female    384
# Name: count, dtype: int64
# /tmp/ipykernel_18171/2924419213.py:62: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   X_train_60m_40f = X_train_60m_40f.groupby('gender').apply(lambda x: x.sample(n=target_male_count if x['gender'].iloc[0] == 'male' else target_female_count, random_state=42)).reset_index(drop=True)
# gender     female  male
# emotion
# angry          49    77
# calm           50    76
# disgust        50    77
# fearful        48    77
# happy          50    77
# neutral        38    38
# sad            49    77
# surprised      50    77

# %%
target_male_count = 480
target_female_count = 480

# Separate neutral and non-neutral emotions
neutral_data = X_train[X_train['emotion'] == 'neutral']
non_neutral_data = X_train[X_train['emotion'] != 'neutral']
print("NON",non_neutral_data['emotion'].value_counts())

# Separate neutral data by gender
neutral_males = neutral_data[neutral_data['gender'] == 'male']
neutral_females = neutral_data[neutral_data['gender'] == 'female']

# Count males and females in neutral data
neutral_male_count = len(neutral_males)
neutral_female_count = len(neutral_females)

# Separate non-neutral data by gender
non_neutral_males = non_neutral_data[non_neutral_data['gender'] == 'male']
non_neutral_females = non_neutral_data[non_neutral_data['gender'] == 'female']

# Calculate the current counts
current_male_count = len(non_neutral_males)
current_female_count = len(non_neutral_females)

# Calculate the number to drop for each gender
excess_male = max(0, current_male_count - target_male_count + neutral_male_count)
excess_female = max(0, current_female_count - target_female_count + neutral_female_count)

# Calculate how much excess data to drop equally from each emotion
emotion_counts = non_neutral_data['emotion'].value_counts()
emotions = emotion_counts.index

# Determine the number to drop from each emotion for both males and females
drop_per_emotion_male = excess_male / len(emotions) if excess_male > 0 else 0
drop_per_emotion_female = excess_female / len(emotions) if excess_female > 0 else 0

# Drop excess data equally across each emotion
def drop_excess(data, drop_per_emotion):
    # Initialize an empty DataFrame to store the result
    reduced_data = pd.DataFrame()
    for emotion in emotions:
        emotion_data = data[data['emotion'] == emotion]
        if drop_per_emotion > 0:
            # Drop excess samples from the emotion data
            if len(emotion_data) > drop_per_emotion:
                sampled_data = emotion_data.sample(n=len(emotion_data) - int(drop_per_emotion), random_state=42)
            else:
                sampled_data = emotion_data
        else:
            sampled_data = emotion_data
        reduced_data = pd.concat([reduced_data, sampled_data])
    return reduced_data

# Apply the dropping function
reduced_males = drop_excess(non_neutral_males, drop_per_emotion_male)
reduced_females = drop_excess(non_neutral_females, drop_per_emotion_female)

# Combine neutral data with the reduced non-neutral data
X_train_50m_50f = pd.concat([neutral_data, reduced_males, reduced_females])

# Ensure we reach the exact size of target counts
X_train_50m_50f = X_train_balanced.groupby('gender').apply(lambda x: x.sample(n=target_male_count if x['gender'].iloc[0] == 'male' else target_female_count, random_state=42)).reset_index(drop=True)

# Check the final shape and balance
print(X_train_50m_50f.shape)  # Should be (960, 11)
print(X_train_50m_50f['emotion'].value_counts())  # Check distribution of emotions
print(X_train_50m_50f['gender'].value_counts())   # Should be 480 males and 480 females

X_train_50m_50f.groupby(['emotion', 'gender']).size().unstack()
# Out:
# NON emotion
# happy        154
# angry        154
# disgust      154
# surprised    154
# sad          154
# calm         153
# fearful      153
# Name: count, dtype: int64
# (960, 11)
# emotion
# happy        128
# disgust      128
# calm         127
# sad          126
# surprised    126
# fearful      125
# angry        124
# neutral       76
# Name: count, dtype: int64
# gender
# female    480
# male      480
# Name: count, dtype: int64
# /tmp/ipykernel_18171/3613549186.py:62: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   X_train_50m_50f = X_train_balanced.groupby('gender').apply(lambda x: x.sample(n=target_male_count if x['gender'].iloc[0] == 'male' else target_female_count, random_state=42)).reset_index(drop=True)
# gender     female  male
# emotion
# angry          62    62
# calm           64    63
# disgust        64    64
# fearful        62    63
# happy          64    64
# neutral        38    38
# sad            63    63
# surprised      63    63

# %%
train_df_50m_50f = X_train_50m_50f.copy()
train_df_40m_60f = X_train_40m_60f.copy()
train_df_60m_40f = X_train_60m_40f.copy()



test_df = X_test.copy()


# Save to CSV files
train_df_50m_50f.to_csv('videotrain_set_50m_50f.csv', index=False)
train_df_40m_60f.to_csv('videotrain_set_40m_60f.csv', index=False)
train_df_60m_40f.to_csv('videotrain_set_60m_40f.csv', index=False)

test_df.to_csv('videotest_set.csv', index=False)

# %%
train_videos_path=list(X_train_50m_50f.dir)
test_videos_path = list(X_test.dir)
#print(videos_path)

# %%
print(len(train_videos_path))
# Out:
# 960

# %%
Video(rd.sample(train_videos_path,1)[0],embed=True,width=300,height=300)
show_video(rd.sample(train_videos_path,1)[0])

# %%
SEQUENCE_LENGTH=20
(IMAGE_HEIGHT, IMAGE_WIDTH)=48,48

# %%
detector = dlib.get_frontal_face_detector()

def frames_extraction(video_path):
    '''
    This function will extract the required frames from a video after detect face and resizing and normalizing them.
    Args:
        video_path: The path of the video in the disk, whose frames are to be extracted.
    Returns:
        frames_list: A list containing the resized and normalized frames of the video (faces).
    '''

    # Declare a list to store video frames.
    frames_list = []
    
    # Read the Video File using the VideoCapture object.
    video_reader = cv2.VideoCapture(video_path)
 
    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
 
    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)
 
    # Iterate through the Video Frames.
    # for frame_counter in tqdm_notebook(range(SEQUENCE_LENGTH)):
    for frame_counter in range(SEQUENCE_LENGTH):

         # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
 
        # Reading the frame from the video. 
        success, frame = video_reader.read() 
        # Check if Video frame is not successfully read then break the loop
        if not success:
            break
 
        # detect and crop face in frame.
        faces = detector(frame, 0) 
        crop_img = frame[faces[0].top():faces[0].bottom(),faces[0].left():faces[0].right()]
        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(crop_img, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        resized_frame=cv2.cvtColor(resized_frame, cv2.COLOR_RGB2GRAY)
        
        # Append the normalized frame into the frames list
        frames_list.append(resized_frame)
    
    # Release the VideoCapture object. 
    video_reader.release()
 
    # Return the frames list.
    return frames_list

# %%
frames=frames_extraction(rd.sample(train_videos_path,1)[0])

# %%
print(len(frames))
# Out:
# 20

# %%
import time,sys
start = time.time()
t=frames_extraction('/var/scratch/mpa326/Ravdess_dataset/Video_Speech/Actor_03/02-01-01-01-01-01-03.mp4')
end = time.time()
print("The time of execution of above program is :", end-start)
# Out:
# The time of execution of above program is : 4.247759103775024

# %%
emotions_en=df_video_only.emotion.unique()

# %%
print(emotions_en)
# Out:
# ['neutral' 'calm' 'happy' 'sad' 'angry' 'fearful' 'disgust' 'surprised']

# %%
def create_dataset():

    '''
    This function will extract the data of the selected classes and create the required dataset.
    Returns:
        features:          A list containing the extracted frames of the videos.
        labels:            A list containing the indexes of the classes associated with the videos.
        video_files_paths: A list containing the paths of the videos in the disk.
    '''
 
    # Declared Empty Lists to store the features, labels and video file path values.
    features = []
    labels = []
    genders = []
    video_files_paths = []
    
    # Iterating through all the classes mentioned in the classes list
    for class_index, class_name in enumerate(tqdm_notebook(emotions_en)):
            
            # Display the name of the class whose data is being extracted.
            print(f'Extracting Data of Class: {class_name}')
            
            # Get the list of video files present in the specific class name directory.
            files_list = list(X_test.dir[X_test.emotion == class_name])
            
            # Iterate through all the files present in the files list.
            for video_file_path in files_list:
                # Extract the frames of the video file.
                frames = frames_extraction(video_file_path)
                
                # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
                # So ignore the vides having frames less than the SEQUENCE_LENGTH.
                if len(frames) == SEQUENCE_LENGTH:
    
                    # Append the data to their repective lists.
                    features.append(frames)
                    labels.append(class_index)
                    genders.append(X_test.gender[X_test.dir == video_file_path].values[0])
                    video_files_paths.append(video_file_path)
    
        # Converting the list to numpy arrays
    features = np.asarray(features)
    labels = np.array(labels)
    genders = np.array(genders)
        
        # Return the frames, class index, and video file path.
    return {'features':features, 'labels':labels, 'genders':genders, 'video_files_paths':video_files_paths}

# %%
df=create_dataset()
datafile = open('video_test_common', 'ab')
pickle.dump(df, datafile)
datafile.close()
print(len(df['features']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df=create_dataset()
#       2 datafile = open('video_train_50m_50f', 'ab')
#       3 pickle.dump(df, datafile)
#
# Cell In[2], line 18, in create_dataset()
#      15 video_files_paths = []
#      17 # Iterating through all the classes mentioned in the classes list
# ---> 18 for class_index, class_name in enumerate(tqdm_notebook(emotions_en)):
#      19
#      20         # Display the name of the class whose data is being extracted.
#      21         print(f'Extracting Data of Class: {class_name}')
#      23         # Get the list of video files present in the specific class name directory.
#
# NameError: name 'tqdm_notebook' is not defined

# %%
video_file_paths = df.get('video_files_paths', [])
df = pd.DataFrame(video_file_paths, columns=['video_file_path'])
# Save to CSV
df.to_csv('video_test_paths.csv', index=False)

# %%
# datafile = open('video_data_new2', 'ab')
# pickle.dump(df, datafile)
# datafile.close()

# %%
print(len(df['features']))
# Out:
# 1440

# %%
#Audio Feature extracton

# %%
import getData
df_audio=getData.getdata(audio_folder)
df_audio.head()
# Out:
#                                           Audio_file    modality  \
# 0  /var/scratch/mpa326/Ravdess_dataset/Audio_Spee...  audio-only
# 1  /var/scratch/mpa326/Ravdess_dataset/Audio_Spee...  audio-only
# 2  /var/scratch/mpa326/Ravdess_dataset/Audio_Spee...  audio-only
# 3  /var/scratch/mpa326/Ravdess_dataset/Audio_Spee...  audio-only
# 4  /var/scratch/mpa326/Ravdess_dataset/Audio_Spee...  audio-only
#
#   vocal_channel  emotion emotional_intensity                     statement  \
# 0        speech  neutral              normal  Kids are talking by the door
# 1        speech  neutral              normal  Kids are talking by the door
# 2        speech  neutral              normal  Dogs are sitting by the door
# 3        speech  neutral              normal  Dogs are sitting by the door
# 4        speech     calm              normal  Kids are talking by the door
#
#        repetition gender
# 0  1st repetition   male
# 1  2nd repetition   male
# 2  1st repetition   male
# 3  2nd repetition   male
# 4  1st repetition   male

# %%
#For 1D

import torchaudio

def check_channel(Dataframe):
    for i, audio_file in enumerate(Dataframe["Audio_file"]):
        data, rate = torchaudio.load(audio_file)
        data_shape = list(data.shape)
        if data_shape[0] != 1:
          print(f"index: {i}, shape : {data.shape}")

# %%
check_channel(df_audio)
# Out:
# index: 5, shape : torch.Size([2, 172972])
# index: 55, shape : torch.Size([2, 156956])
# index: 247, shape : torch.Size([2, 203403])
# index: 1154, shape : torch.Size([2, 166566])
# index: 1177, shape : torch.Size([2, 209809])

# %%
x, sr = librosa.load(df_audio.Audio_file[5])
Audio(data=x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x, sr =librosa.load(df_audio.Audio_file[5], duration=2.5, offset=0.6)
Audio(data=x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate=0.8)

def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)

def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=1)

# %%
def extract_features(data,sample_rate):
    # ZCR
    result = np.array([])
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    result=np.hstack((result, zcr)) # stacking horizontally

    # Chroma_stft
    stft = np.abs(librosa.stft(data))
    chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
    result = np.hstack((result, chroma_stft)) # stacking horizontally

    # MFCC
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mfcc)) # stacking horizontally

    # Root Mean Square Value
    rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
    result = np.hstack((result, rms)) # stacking horizontally

    # MelSpectogram
    mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mel)) # stacking horizontally
    
    return result

def get_features(path):
    # duration and offset are used to take care of the no audio in start and the ending of each audio files as seen above.
    data, sample_rate = librosa.load(path, duration=2.5, offset=0.6)
    
    # without augmentation
    res1 = extract_features(data,sample_rate)
    result = np.array(res1)
    
    # data with noise
    noise_data = noise(data)
    res2 = extract_features(noise_data,sample_rate)
    result = np.vstack((result, res2)) # stacking vertically
    
    # data with stretching and pitching
    new_data = stretch(data)
    data_stretch_pitch = pitch(new_data, sample_rate)
    res3 = extract_features(data_stretch_pitch,sample_rate)
    result = np.vstack((result, res3)) # stacking vertically
    
    return result

# %%
emotions = []
features = []
audio_path = []
genders = []

for class_index, class_name in enumerate(emotions_en):
    # Display the name of the class whose data is being extracted.
    print(f'Extracting Data of Class: {class_name}')
    files_list = list(df_audio.Audio_file[df_audio.emotion == class_name])

    for video_file_path in files_list:
        emotions.append(class_index)
        features.append(get_features(video_file_path))
        genders.append(df_audio.gender[df_audio.Audio_file == video_file_path].values[0])
        audio_path.append(video_file_path)
# Out:
# Extracting Data of Class: neutral
# Extracting Data of Class: calm
# Extracting Data of Class: happy
# Extracting Data of Class: sad
# Extracting Data of Class: angry
# Extracting Data of Class: fearful
# Extracting Data of Class: disgust
# Extracting Data of Class: surprised

# %%
df_={'features':features, 'labels':emotions, 'audio_files_paths':audio_path}
datafile = open('data_audio_1D', 'ab')
pickle.dump(df_, datafile)                     
datafile.close()

# %%
import pickle
import numpy as np
import pandas as pd

# Load the pickle file
with open('/var/scratch/mpa326/data_audio_1D', 'rb') as file:
    data = pickle.load(file)
df = data['features']

#df = pd.DataFrame(df, columns=['features'])

# Print the shape of the data
len(df)
# Out:
# 1440

# %%
#2D audio features
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 features.shape
#
# NameError: name 'features' is not defined

# %%
def load_spec(audio_path, mode=0):

  wave, sr = librosa.load(audio_path,sr=None,mono=True)

  s, _ = librosa.effects.trim(wave,top_db=60)
  
    
  # generate (mel)spectrogram / mfcc
  if(mode == 1):
    s = librosa.feature.melspectrogram(y=s, sr=sr, hop_length=512)
  elif(mode == 2):

    s = librosa.feature.mfcc(y=s, sr=sr, n_mfcc=40)
  else:
    freqs, times, s = librosa.reassigned_spectrogram(y=s, sr=sr, hop_length=512)
    
  return s,sr

# %%
y, sr = load_spec(df_audio.Audio_file[8],1)

from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
import matplotlib.pyplot as plt
#from matplotlib.figure import Figure
fig = plt.Figure()
canvas = FigureCanvas(fig)
ax = fig.add_subplot(111)
ax.set_axis_off()
p = librosa.display.specshow(librosa.power_to_db(y), ax=ax)
fig.savefig('spec.png',bbox_inches='tight',pad_inches=0.0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 y, sr = load_spec(df_audio.Audio_file[8],1)
#       3 from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
#       4 import matplotlib.pyplot as plt
#
# NameError: name 'df_audio' is not defined

# %%
cv2.imread('spec.png').shape
# Out:
# (369, 496, 3)

# %%
plt.imshow(cv2.imread('spec.png'))

# %%
df_audio.Audio_file[8].split('/')[-1].split('.')[0]
# Out:
# '03-01-02-02-01-01-01'

# %%
train_df = pd.read_csv('audio_train_set.csv')
val_df = pd.read_csv('audio_val_set.csv')
test_df = pd.read_csv('audio_test_set.csv')

# Extract paths, gender, and emotion labels from train set
train_paths = train_df['Melspec path']  # Replace 'data' with the actual column name for paths if different
train_genders = train_df['gender']
train_emotions = train_df['emotion']

# Extract paths, gender, and emotion labels from validation set
val_paths = val_df['Melspec path']  # Replace 'data' with the actual column name for paths if different
val_genders = val_df['gender']
val_emotions = val_df['emotion']

# Extract paths, gender, and emotion labels from test set
test_paths = test_df['Melspec path']  # Replace 'data' with the actual column name for paths if different
test_genders = test_df['gender']
test_emotions = test_df['emotion']

# Print or verify the extracted data
print("Train paths:", train_paths.head())
print("Train genders:", train_genders.head())
print("Train emotions:", train_emotions.head())

print("Validation paths:", val_paths.head())
print("Validation genders:", val_genders.head())
print("Validation emotions:", val_emotions.head())

print("Test paths:", test_paths.head())
print("Test genders:", test_genders.head())
print("Test emotions:", test_emotions.head())
# Out:
# Train paths: 0    /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 1    /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 2    /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 3    /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 4    /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# Name: Melspec path, dtype: object
# Train genders: 0    female
# 1    female
# 2      male
# 3      male
# 4    female
# Name: gender, dtype: object
# Train emotions: 0        sad
# 1    fearful
# 2      angry
# 3    neutral
# 4      angry
# Name: emotion, dtype: object
# Validation paths: 0    /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 1    /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 2    /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 3    /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 4    /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# Name: Melspec path, dtype: object
# Validation genders: 0      male
# 1    female
# 2      male
# 3    female
# 4      male
# Name: gender, dtype: object
# Validation emotions: 0      fearful
# 1        angry
# 2    surprised
# 3          sad
# 4         calm
# Name: emotion, dtype: object
# Test paths: 0    /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 1    /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 2    /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 3    /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 4    /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# Name: Melspec path, dtype: object
# Test genders: 0      male
# 1      male
# 2    female
# 3      male
# 4    female
# Name: gender, dtype: object
# Test emotions: 0    surprised
# 1    surprised
# 2    surprised
# 3      fearful
# 4    surprised
# Name: emotion, dtype: object

# %%
import os
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.max_colwidth', None) # Show full column content
pd.set_option('display.expand_frame_repr', False) 
def create_new_path(old_path):
    # Extract the filename from the old path
    filename = os.path.basename(old_path)
    # Replace the first "02" with "03"
    new_filename = filename.replace("02", "03", 1)
    # Change the extension from .mp4 to .png
    new_filename = os.path.splitext(new_filename)[0] + '.png'
    # Create the new path
    new_path = f"/var/scratch/mpa326/ravdess_melspec_new/{new_filename}"
    return new_path
file_path1 = '/var/scratch/mpa326/Ravdess_code/Video_paths_for_audio_files/video_train_paths_50m_50f.csv'
file_path2 = '/var/scratch/mpa326/Ravdess_code/Video_paths_for_audio_files/video_train_paths_40m_60f.csv'
file_path3 = '/var/scratch/mpa326/Ravdess_code/Video_paths_for_audio_files/video_train_paths_60m_40f.csv'
file_path4 = '/var/scratch/mpa326/Ravdess_code/video_test_paths.csv'
df1 = pd.read_csv(file_path1)
df2 = pd.read_csv(file_path2)
df3 = pd.read_csv(file_path3)
df4 = pd.read_csv(file_path4)
X_train_aud_50m_50f = pd.DataFrame()
X_train_aud_40m_60f = pd.DataFrame()
X_train_aud_60m_40f = pd.DataFrame()
X_test_aud = pd.DataFrame()
X_train_aud_50m_50f['melspec_path'] = df1['video_file_path'].apply(create_new_path)
X_train_aud_40m_60f['melspec_path'] = df2['video_file_path'].apply(create_new_path)
X_train_aud_60m_40f['melspec_path'] = df3['video_file_path'].apply(create_new_path)
X_test_aud['melspec_path'] = df4['video_file_path'].apply(create_new_path)
print(X_train_aud_m50_f50)
X_train_aud_50m_50f.to_csv('paths_train_audio_50m_50f.csv', index=False)
X_train_aud_40m_60f.to_csv('paths_train_audio_40m_60f.csv', index=False)
X_train_aud_60m_40f.to_csv('paths_train_audio_60m_40f.csv', index=False)
X_test_aud.to_csv('paths_test_audio.csv', index=False)
# Out:
#                                                          melspec_path
# 0    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-04.png
# 1    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-24.png
# 2    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-10.png
# 3    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-10.png
# 4    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-10.png
# 5    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-14.png
# 6    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-08.png
# 7    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-04.png
# 8    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-12.png
# 9    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-24.png
# 10   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-02.png
# 11   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-02.png
# 12   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-06.png
# 13   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-18.png
# 14   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-02.png
# 15   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-20.png
# 16   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-06.png
# 17   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-06.png
# 18   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-04.png
# 19   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-14.png
# 20   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-18.png
# 21   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-12.png
# 22   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-24.png
# 23   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-18.png
# 24   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-10.png
# 25   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-16.png
# 26   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-06.png
# 27   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-20.png
# 28   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-08.png
# 29   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-08.png
# 30   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-02.png
# 31   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-16.png
# 32   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-24.png
# 33   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-12.png
# 34   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-20.png
# 35   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-22.png
# 36   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-22.png
# 37   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-20.png
# 38   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-15.png
# 39   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-01.png
# 40   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-21.png
# 41   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-03.png
# 42   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-09.png
# 43   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-09.png
# 44   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-23.png
# 45   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-23.png
# 46   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-07.png
# 47   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-17.png
# 48   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-03.png
# 49   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-19.png
# 50   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-01.png
# 51   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-17.png
# 52   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-03.png
# 53   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-07.png
# 54   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-11.png
# 55   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-23.png
# 56   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-01.png
# 57   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-21.png
# 58   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-05.png
# 59   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-13.png
# 60   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-09.png
# 61   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-23.png
# 62   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-13.png
# 63   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-11.png
# 64   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-01.png
# 65   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-17.png
# 66   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-17.png
# 67   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-13.png
# 68   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-05.png
# 69   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-11.png
# 70   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-05.png
# 71   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-13.png
# 72   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-21.png
# 73   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-11.png
# 74   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-15.png
# 75   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-15.png
# 76   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-04.png
# 77   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-06.png
# 78   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-16.png
# 79   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-16.png
# 80   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-04.png
# 81   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-10.png
# 82   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-24.png
# 83   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-06.png
# 84   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-16.png
# 85   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-02.png
# 86   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-20.png
# 87   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-06.png
# 88   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-04.png
# 89   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-20.png
# 90   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-20.png
# 91   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-20.png
# 92   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-02.png
# 93   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-08.png
# 94   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-16.png
# 95   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-08.png
# 96   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-14.png
# 97   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-24.png
# 98   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-20.png
# 99   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-14.png
# 100  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-12.png
# 101  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-10.png
# 102  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-06.png
# 103  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-10.png
# 104  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-18.png
# 105  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-14.png
# 106  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-16.png
# 107  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-10.png
# 108  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-18.png
# 109  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-04.png
# 110  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-10.png
# 111  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-22.png
# 112  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-12.png
# 113  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-04.png
# 114  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-14.png
# 115  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-08.png
# 116  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-24.png
# 117  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-22.png
# 118  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-16.png
# 119  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-08.png
# 120  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-14.png
# 121  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-18.png
# 122  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-20.png
# 123  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-20.png
# 124  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-08.png
# 125  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-22.png
# 126  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-10.png
# 127  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-02.png
# 128  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-14.png
# 129  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-06.png
# 130  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-24.png
# 131  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-02.png
# 132  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-22.png
# 133  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-04.png
# 134  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-24.png
# 135  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-10.png
# 136  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-12.png
# 137  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-22.png
# 138  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-12.png
# 139  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-18.png
# 140  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-07.png
# 141  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-21.png
# 142  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-23.png
# 143  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-19.png
# 144  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-07.png
# 145  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-19.png
# 146  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-21.png
# 147  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-03.png
# 148  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-11.png
# 149  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-17.png
# 150  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-15.png
# 151  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-15.png
# 152  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-23.png
# 153  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-23.png
# 154  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-07.png
# 155  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-11.png
# 156  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-03.png
# 157  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-21.png
# 158  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-13.png
# 159  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-15.png
# 160  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-07.png
# 161  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-11.png
# 162  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-19.png
# 163  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-17.png
# 164  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-17.png
# 165  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-11.png
# 166  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-03.png
# 167  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-01.png
# 168  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-07.png
# 169  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-21.png
# 170  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-05.png
# 171  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-17.png
# 172  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-13.png
# 173  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-09.png
# 174  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-17.png
# 175  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-05.png
# 176  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-19.png
# 177  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-03.png
# 178  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-01.png
# 179  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-09.png
# 180  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-09.png
# 181  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-07.png
# 182  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-05.png
# 183  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-21.png
# 184  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-23.png
# 185  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-13.png
# 186  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-01.png
# 187  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-05.png
# 188  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-03.png
# 189  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-17.png
# 190  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-15.png
# 191  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-01.png
# 192  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-09.png
# 193  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-11.png
# 194  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-03.png
# 195  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-21.png
# 196  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-05.png
# 197  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-17.png
# 198  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-03.png
# 199  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-07.png
# 200  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-17.png
# 201  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-13.png
# 202  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-09.png
# 203  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-18.png
# 204  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-20.png
# 205  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-14.png
# 206  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-22.png
# 207  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-18.png
# 208  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-06.png
# 209  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-20.png
# 210  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-06.png
# 211  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-04.png
# 212  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-08.png
# 213  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-04.png
# 214  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-22.png
# 215  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-24.png
# 216  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-16.png
# 217  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-16.png
# 218  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-02.png
# 219  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-10.png
# 220  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-10.png
# 221  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-18.png
# 222  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-24.png
# 223  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-24.png
# 224  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-08.png
# 225  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-06.png
# 226  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-14.png
# 227  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-02.png
# 228  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-02.png
# 229  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-06.png
# 230  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-20.png
# 231  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-02.png
# 232  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-22.png
# 233  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-10.png
# 234  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-20.png
# 235  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-08.png
# 236  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-02.png
# 237  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-16.png
# 238  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-18.png
# 239  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-22.png
# 240  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-02.png
# 241  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-22.png
# 242  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-16.png
# 243  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-08.png
# 244  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-20.png
# 245  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-04.png
# 246  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-14.png
# 247  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-14.png
# 248  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-02.png
# 249  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-12.png
# 250  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-02.png
# 251  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-24.png
# 252  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-04.png
# 253  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-10.png
# 254  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-24.png
# 255  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-12.png
# 256  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-20.png
# 257  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-04.png
# 258  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-06.png
# 259  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-18.png
# 260  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-04.png
# 261  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-12.png
# 262  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-14.png
# 263  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-10.png
# 264  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-20.png
# 265  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-08.png
# 266  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-12.png
# 267  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-11.png
# 268  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-23.png
# 269  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-21.png
# 270  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-09.png
# 271  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-03.png
# 272  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-23.png
# 273  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-13.png
# 274  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-13.png
# 275  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-21.png
# 276  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-03.png
# 277  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-09.png
# 278  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-13.png
# 279  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-07.png
# 280  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-23.png
# 281  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-03.png
# 282  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-21.png
# 283  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-07.png
# 284  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-19.png
# 285  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-13.png
# 286  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-11.png
# 287  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-05.png
# 288  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-09.png
# 289  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-09.png
# 290  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-05.png
# 291  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-01.png
# 292  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-17.png
# 293  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-15.png
# 294  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-01.png
# 295  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-11.png
# 296  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-09.png
# 297  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-01.png
# 298  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-01.png
# 299  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-21.png
# 300  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-19.png
# 301  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-07.png
# 302  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-01.png
# 303  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-23.png
# 304  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-03.png
# 305  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-07.png
# 306  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-09.png
# 307  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-19.png
# 308  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-07.png
# 309  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-01.png
# 310  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-19.png
# 311  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-19.png
# 312  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-05.png
# 313  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-17.png
# 314  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-05.png
# 315  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-23.png
# 316  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-21.png
# 317  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-17.png
# 318  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-13.png
# 319  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-13.png
# 320  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-05.png
# 321  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-19.png
# 322  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-17.png
# 323  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-19.png
# 324  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-07.png
# 325  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-17.png
# 326  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-17.png
# 327  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-07.png
# 328  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-17.png
# 329  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-23.png
# 330  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-21.png
# 331  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-16.png
# 332  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-02.png
# 333  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-04.png
# 334  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-04.png
# 335  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-18.png
# 336  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-22.png
# 337  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-14.png
# 338  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-16.png
# 339  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-20.png
# 340  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-12.png
# 341  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-02.png
# 342  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-16.png
# 343  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-24.png
# 344  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-10.png
# 345  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-14.png
# 346  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-20.png
# 347  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-08.png
# 348  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-06.png
# 349  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-18.png
# 350  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-10.png
# 351  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-18.png
# 352  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-12.png
# 353  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-20.png
# 354  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-22.png
# 355  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-06.png
# 356  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-04.png
# 357  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-02.png
# 358  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-08.png
# 359  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-12.png
# 360  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-18.png
# 361  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-04.png
# 362  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-02.png
# 363  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-04.png
# 364  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-06.png
# 365  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-18.png
# 366  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-14.png
# 367  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-24.png
# 368  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-16.png
# 369  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-04.png
# 370  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-08.png
# 371  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-16.png
# 372  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-08.png
# 373  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-14.png
# 374  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-24.png
# 375  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-08.png
# 376  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-10.png
# 377  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-24.png
# 378  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-12.png
# 379  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-02.png
# 380  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-24.png
# 381  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-02.png
# 382  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-12.png
# 383  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-04.png
# 384  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-18.png
# 385  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-12.png
# 386  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-22.png
# 387  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-14.png
# 388  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-06.png
# 389  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-24.png
# 390  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-20.png
# 391  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-10.png
# 392  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-14.png
# 393  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-22.png
# 394  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-03.png
# 395  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-15.png
# 396  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-01.png
# 397  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-19.png
# 398  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-17.png
# 399  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-19.png
# 400  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-11.png
# 401  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-17.png
# 402  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-07.png
# 403  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-11.png
# 404  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-19.png
# 405  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-03.png
# 406  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-09.png
# 407  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-05.png
# 408  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-07.png
# 409  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-01.png
# 410  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-09.png
# 411  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-09.png
# 412  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-11.png
# 413  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-07.png
# 414  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-17.png
# 415  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-21.png
# 416  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-03.png
# 417  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-05.png
# 418  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-19.png
# 419  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-13.png
# 420  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-15.png
# 421  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-11.png
# 422  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-19.png
# 423  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-03.png
# 424  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-21.png
# 425  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-23.png
# 426  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-21.png
# 427  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-09.png
# 428  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-01.png
# 429  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-23.png
# 430  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-03.png
# 431  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-21.png
# 432  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-03.png
# 433  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-07.png
# 434  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-17.png
# 435  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-15.png
# 436  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-23.png
# 437  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-19.png
# 438  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-07.png
# 439  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-01.png
# 440  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-15.png
# 441  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-07.png
# 442  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-17.png
# 443  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-15.png
# 444  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-01.png
# 445  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-07.png
# 446  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-19.png
# 447  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-05.png
# 448  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-01.png
# 449  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-11.png
# 450  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-03.png
# 451  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-05.png
# 452  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-13.png
# 453  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-23.png
# 454  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-01.png
# 455  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-21.png
# 456  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-09.png
# 457  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-22.png
# 458  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-04.png
# 459  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-02.png
# 460  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-16.png
# 461  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-08.png
# 462  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-08.png
# 463  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-18.png
# 464  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-08.png
# 465  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-06.png
# 466  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-20.png
# 467  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-22.png
# 468  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-20.png
# 469  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-14.png
# 470  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-08.png
# 471  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-10.png
# 472  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-20.png
# 473  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-22.png
# 474  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-24.png
# 475  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-16.png
# 476  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-16.png
# 477  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-06.png
# 478  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-04.png
# 479  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-04.png
# 480  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-22.png
# 481  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-06.png
# 482  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-24.png
# 483  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-14.png
# 484  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-20.png
# 485  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-08.png
# 486  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-14.png
# 487  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-24.png
# 488  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-06.png
# 489  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-24.png
# 490  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-16.png
# 491  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-18.png
# 492  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-12.png
# 493  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-12.png
# 494  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-20.png
# 495  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-10.png
# 496  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-12.png
# 497  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-20.png
# 498  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-18.png
# 499  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-08.png
# 500  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-06.png
# 501  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-18.png
# 502  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-12.png
# 503  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-24.png
# 504  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-04.png
# 505  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-22.png
# 506  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-02.png
# 507  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-04.png
# 508  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-04.png
# 509  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-16.png
# 510  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-02.png
# 511  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-16.png
# 512  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-24.png
# 513  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-10.png
# 514  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-16.png
# 515  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-02.png
# 516  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-14.png
# 517  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-24.png
# 518  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-14.png
# 519  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-03.png
# 520  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-07.png
# 521  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-01.png
# 522  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-03.png
# 523  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-11.png
# 524  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-11.png
# 525  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-11.png
# 526  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-23.png
# 527  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-15.png
# 528  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-17.png
# 529  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-15.png
# 530  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-09.png
# 531  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-19.png
# 532  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-11.png
# 533  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-09.png
# 534  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-07.png
# 535  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-19.png
# 536  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-23.png
# 537  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-05.png
# 538  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-09.png
# 539  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-21.png
# 540  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-11.png
# 541  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-07.png
# 542  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-13.png
# 543  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-03.png
# 544  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-23.png
# 545  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-03.png
# 546  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-11.png
# 547  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-19.png
# 548  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-11.png
# 549  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-17.png
# 550  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-19.png
# 551  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-23.png
# 552  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-01.png
# 553  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-17.png
# 554  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-23.png
# 555  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-23.png
# 556  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-13.png
# 557  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-15.png
# 558  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-01.png
# 559  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-11.png
# 560  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-03.png
# 561  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-17.png
# 562  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-13.png
# 563  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-15.png
# 564  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-05.png
# 565  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-17.png
# 566  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-15.png
# 567  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-07.png
# 568  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-07.png
# 569  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-19.png
# 570  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-09.png
# 571  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-01.png
# 572  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-01.png
# 573  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-05.png
# 574  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-17.png
# 575  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-21.png
# 576  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-03.png
# 577  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-21.png
# 578  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-09.png
# 579  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-05.png
# 580  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-19.png
# 581  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-12.png
# 582  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-22.png
# 583  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-24.png
# 584  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-10.png
# 585  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-24.png
# 586  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-12.png
# 587  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-08.png
# 588  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-14.png
# 589  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-14.png
# 590  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-08.png
# 591  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-02.png
# 592  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-10.png
# 593  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-12.png
# 594  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-20.png
# 595  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-04.png
# 596  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-06.png
# 597  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-20.png
# 598  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-02.png
# 599  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-08.png
# 600  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-08.png
# 601  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-06.png
# 602  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-22.png
# 603  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-08.png
# 604  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-12.png
# 605  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-02.png
# 606  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-20.png
# 607  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-10.png
# 608  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-24.png
# 609  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-22.png
# 610  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-20.png
# 611  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-18.png
# 612  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-20.png
# 613  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-10.png
# 614  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-04.png
# 615  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-18.png
# 616  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-08.png
# 617  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-14.png
# 618  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-24.png
# 619  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-20.png
# 620  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-10.png
# 621  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-04.png
# 622  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-16.png
# 623  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-14.png
# 624  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-02.png
# 625  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-06.png
# 626  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-16.png
# 627  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-04.png
# 628  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-02.png
# 629  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-16.png
# 630  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-22.png
# 631  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-04.png
# 632  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-16.png
# 633  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-24.png
# 634  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-20.png
# 635  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-04.png
# 636  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-18.png
# 637  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-10.png
# 638  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-20.png
# 639  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-04.png
# 640  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-22.png
# 641  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-04.png
# 642  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-24.png
# 643  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-21.png
# 644  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-15.png
# 645  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-19.png
# 646  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-03.png
# 647  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-11.png
# 648  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-13.png
# 649  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-09.png
# 650  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-07.png
# 651  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-03.png
# 652  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-11.png
# 653  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-19.png
# 654  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-13.png
# 655  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-15.png
# 656  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-03.png
# 657  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-23.png
# 658  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-07.png
# 659  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-11.png
# 660  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-21.png
# 661  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-17.png
# 662  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-21.png
# 663  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-17.png
# 664  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-13.png
# 665  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-15.png
# 666  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-17.png
# 667  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-05.png
# 668  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-13.png
# 669  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-15.png
# 670  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-21.png
# 671  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-23.png
# 672  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-09.png
# 673  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-05.png
# 674  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-17.png
# 675  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-17.png
# 676  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-11.png
# 677  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-23.png
# 678  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-01.png
# 679  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-01.png
# 680  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-01.png
# 681  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-21.png
# 682  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-07.png
# 683  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-07.png
# ...
# 732  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-08.png
# 733  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-08.png
# 734  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-10.png
# 735  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-22.png
# 736  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-12.png
# 737  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-08.png
# 738  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-20.png
# 739  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-18.png
# 740  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-24.png
# 741  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-16.png
# 742  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-04.png
# 743  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-08.png
# 744  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-20.png
# 745  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-24.png
# 746  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-24.png
# 747  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-02.png
# 748  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-18.png
# 749  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-08.png
# 750  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-06.png
# 751  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-22.png
# 752  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-16.png
# 753  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-10.png
# 754  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-02.png
# 755  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-14.png
# 756  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-24.png
# 757  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-06.png
# 758  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-16.png
# 759  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-16.png
# 760  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-22.png
# 761  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-20.png
# 762  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-12.png
# 763  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-20.png
# 764  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-20.png
# 765  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-16.png
# 766  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-14.png
# 767  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-20.png
# 768  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-08.png
# 769  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-14.png
# 770  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-05.png
# 771  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-11.png
# 772  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-17.png
# 773  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-13.png
# 774  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-19.png
# 775  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-21.png
# 776  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-01.png
# 777  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-09.png
# 778  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-09.png
# 779  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-17.png
# 780  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-21.png
# 781  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-15.png
# 782  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-07.png
# 783  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-23.png
# 784  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-19.png
# 785  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-15.png
# 786  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-07.png
# 787  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-19.png
# 788  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-15.png
# 789  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-07.png
# 790  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-01.png
# 791  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-09.png
# 792  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-17.png
# 793  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-01.png
# 794  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-13.png
# 795  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-09.png
# 796  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-03.png
# 797  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-23.png
# 798  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-17.png
# 799  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-21.png
# 800  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-03.png
# 801  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-11.png
# 802  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-23.png
# 803  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-11.png
# 804  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-11.png
# 805  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-19.png
# 806  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-23.png
# 807  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-15.png
# 808  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-19.png
# 809  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-11.png
# 810  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-05.png
# 811  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-13.png
# 812  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-11.png
# 813  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-03.png
# 814  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-19.png
# 815  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-09.png
# 816  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-09.png
# 817  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-05.png
# 818  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-23.png
# 819  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-05.png
# 820  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-21.png
# 821  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-23.png
# 822  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-09.png
# 823  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-05.png
# 824  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-15.png
# 825  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-03.png
# 826  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-07.png
# 827  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-01.png
# 828  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-23.png
# 829  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-13.png
# 830  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-21.png
# 831  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-17.png
# 832  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-05.png
# 833  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-01.png
# 834  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-04.png
# 835  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-02.png
# 836  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-20.png
# 837  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-14.png
# 838  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-16.png
# 839  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-14.png
# 840  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-18.png
# 841  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-02.png
# 842  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-04.png
# 843  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-12.png
# 844  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-06.png
# 845  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-08.png
# 846  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-10.png
# 847  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-10.png
# 848  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-24.png
# 849  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-20.png
# 850  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-20.png
# 851  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-20.png
# 852  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-06.png
# 853  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-18.png
# 854  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-10.png
# 855  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-24.png
# 856  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-08.png
# 857  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-14.png
# 858  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-06.png
# 859  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-12.png
# 860  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-02.png
# 861  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-02.png
# 862  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-18.png
# 863  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-08.png
# 864  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-22.png
# 865  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-06.png
# 866  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-16.png
# 867  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-04.png
# 868  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-14.png
# 869  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-20.png
# 870  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-08.png
# 871  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-14.png
# 872  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-18.png
# 873  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-18.png
# 874  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-20.png
# 875  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-22.png
# 876  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-24.png
# 877  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-06.png
# 878  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-10.png
# 879  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-04.png
# 880  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-12.png
# 881  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-22.png
# 882  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-12.png
# 883  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-24.png
# 884  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-02.png
# 885  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-10.png
# 886  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-18.png
# 887  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-04.png
# 888  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-16.png
# 889  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-10.png
# 890  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-18.png
# 891  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-22.png
# 892  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-18.png
# 893  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-20.png
# 894  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-08.png
# 895  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-24.png
# 896  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-06.png
# 897  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-05.png
# 898  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-23.png
# 899  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-23.png
# 900  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-17.png
# 901  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-03.png
# 902  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-23.png
# 903  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-15.png
# 904  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-01.png
# 905  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-09.png
# 906  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-03.png
# 907  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-23.png
# 908  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-11.png
# 909  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-11.png
# 910  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-05.png
# 911  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-13.png
# 912  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-15.png
# 913  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-05.png
# 914  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-13.png
# 915  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-21.png
# 916  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-11.png
# 917  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-17.png
# 918  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-07.png
# 919  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-11.png
# 920  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-01.png
# 921  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-09.png
# 922  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-05.png
# 923  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-05.png
# 924  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-19.png
# 925  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-19.png
# 926  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-09.png
# 927  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-03.png
# 928  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-01.png
# 929  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-01.png
# 930  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-03.png
# 931  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-03.png
# 932  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-01.png
# 933  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-07.png
# 934  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-15.png
# 935  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-23.png
# 936  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-19.png
# 937  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-17.png
# 938  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-21.png
# 939  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-07.png
# 940  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-21.png
# 941  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-09.png
# 942  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-01.png
# 943  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-15.png
# 944  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-05.png
# 945  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-19.png
# 946  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-13.png
# 947  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-15.png
# 948  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-09.png
# 949  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-07.png
# 950  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-13.png
# 951  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-03.png
# 952  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-23.png
# 953  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-21.png
# 954  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-05.png
# 955  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-11.png
# 956  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-07.png
# 957  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-17.png
# 958  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-05.png
# 959  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-07.png

# %%
# train_df = train_df.rename(columns={'Melspec path':'melspec_path'})
# val_df = val_df.rename(columns={'Melspec path':'melspec_path'})
# test_df = test_df.rename(columns={'Melspec path':'melspec_path'})

# %%
X_train_aud_50m_50f
# Out:
#                                                          melspec_path
# 0    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-04.png
# 1    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-24.png
# 2    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-10.png
# 3    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-10.png
# 4    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-10.png
# 5    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-14.png
# 6    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-08.png
# 7    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-04.png
# 8    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-12.png
# 9    /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-24.png
# 10   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-02.png
# 11   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-02.png
# 12   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-06.png
# 13   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-18.png
# 14   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-02.png
# 15   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-20.png
# 16   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-06.png
# 17   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-06.png
# 18   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-04.png
# 19   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-14.png
# 20   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-18.png
# 21   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-12.png
# 22   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-24.png
# 23   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-18.png
# 24   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-10.png
# 25   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-16.png
# 26   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-06.png
# 27   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-20.png
# 28   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-08.png
# 29   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-08.png
# 30   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-02.png
# 31   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-16.png
# 32   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-24.png
# 33   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-12.png
# 34   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-20.png
# 35   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-22.png
# 36   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-22.png
# 37   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-20.png
# 38   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-15.png
# 39   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-01.png
# 40   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-21.png
# 41   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-03.png
# 42   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-09.png
# 43   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-09.png
# 44   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-23.png
# 45   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-23.png
# 46   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-07.png
# 47   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-17.png
# 48   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-03.png
# 49   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-19.png
# 50   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-01.png
# 51   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-17.png
# 52   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-03.png
# 53   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-07.png
# 54   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-11.png
# 55   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-23.png
# 56   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-01.png
# 57   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-21.png
# 58   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-05.png
# 59   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-13.png
# 60   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-09.png
# 61   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-23.png
# 62   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-13.png
# 63   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-11.png
# 64   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-01.png
# 65   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-17.png
# 66   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-17.png
# 67   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-13.png
# 68   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-05.png
# 69   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-11.png
# 70   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-05.png
# 71   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-13.png
# 72   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-21.png
# 73   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-11.png
# 74   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-15.png
# 75   /var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-15.png
# 76   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-04.png
# 77   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-06.png
# 78   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-16.png
# 79   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-16.png
# 80   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-04.png
# 81   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-10.png
# 82   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-24.png
# 83   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-06.png
# 84   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-16.png
# 85   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-02.png
# 86   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-20.png
# 87   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-06.png
# 88   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-04.png
# 89   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-20.png
# 90   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-20.png
# 91   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-20.png
# 92   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-02.png
# 93   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-08.png
# 94   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-16.png
# 95   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-08.png
# 96   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-14.png
# 97   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-24.png
# 98   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-20.png
# 99   /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-14.png
# 100  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-12.png
# 101  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-10.png
# 102  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-06.png
# 103  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-10.png
# 104  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-18.png
# 105  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-14.png
# 106  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-16.png
# 107  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-10.png
# 108  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-18.png
# 109  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-04.png
# 110  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-10.png
# 111  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-22.png
# 112  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-12.png
# 113  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-04.png
# 114  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-14.png
# 115  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-08.png
# 116  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-24.png
# 117  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-22.png
# 118  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-16.png
# 119  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-08.png
# 120  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-14.png
# 121  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-18.png
# 122  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-20.png
# 123  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-20.png
# 124  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-08.png
# 125  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-22.png
# 126  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-10.png
# 127  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-02.png
# 128  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-14.png
# 129  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-06.png
# 130  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-24.png
# 131  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-02.png
# 132  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-22.png
# 133  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-04.png
# 134  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-24.png
# 135  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-10.png
# 136  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-12.png
# 137  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-22.png
# 138  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-12.png
# 139  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-18.png
# 140  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-07.png
# 141  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-21.png
# 142  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-23.png
# 143  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-19.png
# 144  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-07.png
# 145  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-19.png
# 146  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-21.png
# 147  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-03.png
# 148  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-11.png
# 149  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-17.png
# 150  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-15.png
# 151  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-15.png
# 152  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-23.png
# 153  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-23.png
# 154  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-07.png
# 155  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-11.png
# 156  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-03.png
# 157  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-21.png
# 158  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-13.png
# 159  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-15.png
# 160  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-07.png
# 161  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-11.png
# 162  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-19.png
# 163  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-17.png
# 164  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-17.png
# 165  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-11.png
# 166  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-03.png
# 167  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-01.png
# 168  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-07.png
# 169  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-21.png
# 170  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-05.png
# 171  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-17.png
# 172  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-13.png
# 173  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-09.png
# 174  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-17.png
# 175  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-05.png
# 176  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-19.png
# 177  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-03.png
# 178  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-01.png
# 179  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-09.png
# 180  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-09.png
# 181  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-07.png
# 182  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-05.png
# 183  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-01-21.png
# 184  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-23.png
# 185  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-13.png
# 186  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-01.png
# 187  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-05.png
# 188  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-03.png
# 189  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-17.png
# 190  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-15.png
# 191  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-01.png
# 192  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-09.png
# 193  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-11.png
# 194  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-01-03.png
# 195  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-02-21.png
# 196  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-05.png
# 197  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-01-02-17.png
# 198  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-02-02-03.png
# 199  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-01-07.png
# 200  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-17.png
# 201  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-01-02-01-13.png
# 202  /var/scratch/mpa326/ravdess_melspec_new/03-01-02-02-01-02-09.png
# 203  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-18.png
# 204  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-20.png
# 205  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-14.png
# 206  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-22.png
# 207  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-18.png
# 208  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-06.png
# 209  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-20.png
# 210  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-06.png
# 211  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-04.png
# 212  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-08.png
# 213  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-04.png
# 214  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-22.png
# 215  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-24.png
# 216  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-16.png
# 217  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-16.png
# 218  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-02.png
# 219  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-10.png
# 220  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-10.png
# 221  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-18.png
# 222  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-24.png
# 223  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-24.png
# 224  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-08.png
# 225  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-06.png
# 226  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-14.png
# 227  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-02.png
# 228  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-02.png
# 229  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-06.png
# 230  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-20.png
# 231  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-02.png
# 232  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-22.png
# 233  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-10.png
# 234  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-20.png
# 235  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-08.png
# 236  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-02.png
# 237  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-16.png
# 238  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-18.png
# 239  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-22.png
# 240  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-02.png
# 241  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-22.png
# 242  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-16.png
# 243  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-08.png
# 244  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-20.png
# 245  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-04.png
# 246  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-14.png
# 247  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-14.png
# 248  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-02.png
# 249  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-12.png
# 250  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-02.png
# 251  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-24.png
# 252  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-04.png
# 253  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-10.png
# 254  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-24.png
# 255  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-12.png
# 256  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-20.png
# 257  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-04.png
# 258  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-06.png
# 259  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-18.png
# 260  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-04.png
# 261  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-12.png
# 262  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-14.png
# 263  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-10.png
# 264  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-20.png
# 265  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-08.png
# 266  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-12.png
# 267  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-11.png
# 268  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-23.png
# 269  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-21.png
# 270  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-09.png
# 271  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-03.png
# 272  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-23.png
# 273  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-13.png
# 274  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-13.png
# 275  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-21.png
# 276  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-03.png
# 277  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-09.png
# 278  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-13.png
# 279  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-07.png
# 280  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-23.png
# 281  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-03.png
# 282  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-21.png
# 283  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-07.png
# 284  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-19.png
# 285  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-13.png
# 286  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-11.png
# 287  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-05.png
# 288  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-09.png
# 289  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-09.png
# 290  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-05.png
# 291  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-01.png
# 292  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-17.png
# 293  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-15.png
# 294  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-01.png
# 295  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-11.png
# 296  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-09.png
# 297  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-01.png
# 298  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-01.png
# 299  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-21.png
# 300  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-02-19.png
# 301  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-07.png
# 302  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-01.png
# 303  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-23.png
# 304  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-03.png
# 305  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-07.png
# 306  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-09.png
# 307  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-19.png
# 308  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-07.png
# 309  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-01.png
# 310  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-19.png
# 311  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-19.png
# 312  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-05.png
# 313  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-17.png
# 314  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-05.png
# 315  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-23.png
# 316  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-21.png
# 317  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-17.png
# 318  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-13.png
# 319  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-13.png
# 320  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-05.png
# 321  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-19.png
# 322  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-17.png
# 323  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-02-19.png
# 324  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-01-07.png
# 325  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-02-01-17.png
# 326  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-02-02-17.png
# 327  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-07.png
# 328  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-02-17.png
# 329  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-01-01-01-23.png
# 330  /var/scratch/mpa326/ravdess_melspec_new/03-01-03-02-01-01-21.png
# 331  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-16.png
# 332  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-02.png
# 333  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-04.png
# 334  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-04.png
# 335  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-18.png
# 336  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-22.png
# 337  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-14.png
# 338  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-16.png
# 339  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-20.png
# 340  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-12.png
# 341  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-02.png
# 342  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-16.png
# 343  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-24.png
# 344  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-10.png
# 345  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-14.png
# 346  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-20.png
# 347  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-08.png
# 348  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-06.png
# 349  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-18.png
# 350  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-10.png
# 351  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-18.png
# 352  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-12.png
# 353  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-20.png
# 354  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-22.png
# 355  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-06.png
# 356  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-04.png
# 357  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-02.png
# 358  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-08.png
# 359  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-12.png
# 360  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-18.png
# 361  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-04.png
# 362  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-02.png
# 363  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-04.png
# 364  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-06.png
# 365  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-18.png
# 366  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-14.png
# 367  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-24.png
# 368  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-16.png
# 369  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-04.png
# 370  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-08.png
# 371  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-16.png
# 372  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-08.png
# 373  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-14.png
# 374  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-24.png
# 375  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-08.png
# 376  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-10.png
# 377  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-24.png
# 378  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-12.png
# 379  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-02.png
# 380  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-24.png
# 381  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-02.png
# 382  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-12.png
# 383  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-04.png
# 384  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-18.png
# 385  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-12.png
# 386  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-22.png
# 387  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-14.png
# 388  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-06.png
# 389  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-24.png
# 390  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-20.png
# 391  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-10.png
# 392  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-14.png
# 393  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-22.png
# 394  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-03.png
# 395  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-15.png
# 396  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-01.png
# 397  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-19.png
# 398  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-17.png
# 399  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-19.png
# 400  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-11.png
# 401  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-17.png
# 402  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-07.png
# 403  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-11.png
# 404  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-19.png
# 405  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-03.png
# 406  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-09.png
# 407  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-05.png
# 408  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-07.png
# 409  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-01.png
# 410  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-09.png
# 411  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-09.png
# 412  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-11.png
# 413  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-07.png
# 414  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-17.png
# 415  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-21.png
# 416  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-03.png
# 417  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-05.png
# 418  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-19.png
# 419  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-13.png
# 420  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-15.png
# 421  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-11.png
# 422  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-19.png
# 423  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-03.png
# 424  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-21.png
# 425  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-23.png
# 426  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-21.png
# 427  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-09.png
# 428  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-01.png
# 429  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-23.png
# 430  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-03.png
# 431  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-21.png
# 432  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-03.png
# 433  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-07.png
# 434  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-17.png
# 435  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-15.png
# 436  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-23.png
# 437  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-19.png
# 438  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-07.png
# 439  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-01.png
# 440  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-15.png
# 441  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-07.png
# 442  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-17.png
# 443  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-15.png
# 444  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-01-01.png
# 445  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-07.png
# 446  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-01-02-19.png
# 447  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-02-05.png
# 448  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-01.png
# 449  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-11.png
# 450  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-01-03.png
# 451  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-05.png
# 452  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-02-02-02-13.png
# 453  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-02-01-23.png
# 454  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-01-01.png
# 455  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-21.png
# 456  /var/scratch/mpa326/ravdess_melspec_new/03-01-04-01-01-02-09.png
# 457  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-22.png
# 458  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-04.png
# 459  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-02.png
# 460  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-16.png
# 461  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-08.png
# 462  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-08.png
# 463  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-18.png
# 464  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-08.png
# 465  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-06.png
# 466  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-20.png
# 467  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-22.png
# 468  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-20.png
# 469  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-14.png
# 470  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-08.png
# 471  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-10.png
# 472  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-20.png
# 473  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-22.png
# 474  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-24.png
# 475  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-16.png
# 476  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-16.png
# 477  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-06.png
# 478  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-04.png
# 479  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-04.png
# 480  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-22.png
# 481  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-06.png
# 482  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-24.png
# 483  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-14.png
# 484  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-20.png
# 485  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-08.png
# 486  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-14.png
# 487  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-24.png
# 488  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-06.png
# 489  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-24.png
# 490  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-16.png
# 491  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-18.png
# 492  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-12.png
# 493  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-12.png
# 494  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-20.png
# 495  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-10.png
# 496  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-12.png
# 497  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-20.png
# 498  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-18.png
# 499  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-08.png
# 500  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-06.png
# 501  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-18.png
# 502  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-12.png
# 503  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-24.png
# 504  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-04.png
# 505  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-22.png
# 506  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-02.png
# 507  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-04.png
# 508  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-04.png
# 509  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-16.png
# 510  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-02.png
# 511  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-16.png
# 512  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-24.png
# 513  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-10.png
# 514  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-16.png
# 515  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-02.png
# 516  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-14.png
# 517  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-24.png
# 518  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-14.png
# 519  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-03.png
# 520  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-07.png
# 521  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-01.png
# 522  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-03.png
# 523  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-11.png
# 524  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-11.png
# 525  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-11.png
# 526  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-23.png
# 527  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-15.png
# 528  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-17.png
# 529  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-15.png
# 530  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-09.png
# 531  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-19.png
# 532  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-11.png
# 533  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-09.png
# 534  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-07.png
# 535  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-19.png
# 536  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-23.png
# 537  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-05.png
# 538  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-09.png
# 539  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-21.png
# 540  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-11.png
# 541  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-07.png
# 542  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-13.png
# 543  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-03.png
# 544  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-23.png
# 545  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-03.png
# 546  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-11.png
# 547  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-19.png
# 548  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-11.png
# 549  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-17.png
# 550  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-19.png
# 551  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-23.png
# 552  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-01.png
# 553  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-17.png
# 554  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-23.png
# 555  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-23.png
# 556  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-13.png
# 557  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-15.png
# 558  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-01.png
# 559  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-11.png
# 560  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-03.png
# 561  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-17.png
# 562  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-02-13.png
# 563  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-15.png
# 564  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-05.png
# 565  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-17.png
# 566  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-15.png
# 567  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-07.png
# 568  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-07.png
# 569  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-19.png
# 570  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-01-09.png
# 571  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-01-01.png
# 572  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-01.png
# 573  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-05.png
# 574  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-17.png
# 575  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-21.png
# 576  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-02-02-03.png
# 577  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-02-01-21.png
# 578  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-01-01-02-09.png
# 579  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-01-05.png
# 580  /var/scratch/mpa326/ravdess_melspec_new/03-01-05-02-01-02-19.png
# 581  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-12.png
# 582  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-22.png
# 583  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-24.png
# 584  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-10.png
# 585  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-24.png
# 586  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-12.png
# 587  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-08.png
# 588  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-14.png
# 589  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-14.png
# 590  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-08.png
# 591  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-02.png
# 592  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-10.png
# 593  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-12.png
# 594  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-20.png
# 595  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-04.png
# 596  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-06.png
# 597  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-20.png
# 598  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-02.png
# 599  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-08.png
# 600  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-08.png
# 601  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-06.png
# 602  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-22.png
# 603  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-08.png
# 604  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-12.png
# 605  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-02.png
# 606  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-20.png
# 607  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-10.png
# 608  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-24.png
# 609  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-22.png
# 610  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-20.png
# 611  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-18.png
# 612  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-20.png
# 613  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-10.png
# 614  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-04.png
# 615  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-18.png
# 616  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-08.png
# 617  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-14.png
# 618  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-24.png
# 619  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-20.png
# 620  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-10.png
# 621  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-04.png
# 622  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-16.png
# 623  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-14.png
# 624  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-02.png
# 625  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-06.png
# 626  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-16.png
# 627  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-04.png
# 628  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-02.png
# 629  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-16.png
# 630  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-22.png
# 631  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-04.png
# 632  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-16.png
# 633  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-24.png
# 634  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-20.png
# 635  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-04.png
# 636  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-18.png
# 637  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-10.png
# 638  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-20.png
# 639  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-04.png
# 640  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-22.png
# 641  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-04.png
# 642  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-24.png
# 643  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-21.png
# 644  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-15.png
# 645  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-19.png
# 646  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-03.png
# 647  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-11.png
# 648  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-13.png
# 649  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-09.png
# 650  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-07.png
# 651  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-03.png
# 652  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-11.png
# 653  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-19.png
# 654  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-13.png
# 655  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-15.png
# 656  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-03.png
# 657  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-23.png
# 658  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-07.png
# 659  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-11.png
# 660  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-21.png
# 661  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-17.png
# 662  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-21.png
# 663  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-17.png
# 664  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-01-13.png
# 665  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-15.png
# 666  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-17.png
# 667  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-05.png
# 668  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-13.png
# 669  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-15.png
# 670  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-21.png
# 671  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-02-02-23.png
# 672  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-02-09.png
# 673  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-05.png
# 674  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-17.png
# 675  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-17.png
# 676  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-02-11.png
# 677  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-23.png
# 678  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-02-01-01.png
# 679  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-01.png
# 680  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-01.png
# 681  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-01-01-01-21.png
# 682  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-01-07.png
# 683  /var/scratch/mpa326/ravdess_melspec_new/03-01-06-02-01-02-07.png
# ...
# 732  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-08.png
# 733  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-08.png
# 734  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-10.png
# 735  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-22.png
# 736  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-12.png
# 737  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-08.png
# 738  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-20.png
# 739  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-18.png
# 740  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-24.png
# 741  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-16.png
# 742  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-04.png
# 743  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-08.png
# 744  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-20.png
# 745  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-24.png
# 746  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-24.png
# 747  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-02.png
# 748  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-18.png
# 749  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-08.png
# 750  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-06.png
# 751  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-22.png
# 752  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-16.png
# 753  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-10.png
# 754  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-02.png
# 755  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-14.png
# 756  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-24.png
# 757  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-06.png
# 758  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-16.png
# 759  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-16.png
# 760  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-22.png
# 761  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-20.png
# 762  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-12.png
# 763  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-20.png
# 764  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-20.png
# 765  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-16.png
# 766  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-14.png
# 767  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-20.png
# 768  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-08.png
# 769  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-14.png
# 770  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-05.png
# 771  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-11.png
# 772  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-17.png
# 773  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-13.png
# 774  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-19.png
# 775  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-21.png
# 776  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-01.png
# 777  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-09.png
# 778  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-09.png
# 779  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-17.png
# 780  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-21.png
# 781  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-15.png
# 782  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-07.png
# 783  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-23.png
# 784  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-19.png
# 785  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-15.png
# 786  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-07.png
# 787  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-19.png
# 788  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-15.png
# 789  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-07.png
# 790  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-01.png
# 791  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-09.png
# 792  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-17.png
# 793  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-01.png
# 794  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-13.png
# 795  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-09.png
# 796  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-03.png
# 797  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-23.png
# 798  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-17.png
# 799  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-21.png
# 800  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-03.png
# 801  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-11.png
# 802  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-23.png
# 803  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-11.png
# 804  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-11.png
# 805  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-19.png
# 806  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-23.png
# 807  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-15.png
# 808  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-19.png
# 809  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-11.png
# 810  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-05.png
# 811  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-13.png
# 812  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-11.png
# 813  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-03.png
# 814  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-19.png
# 815  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-09.png
# 816  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-09.png
# 817  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-05.png
# 818  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-23.png
# 819  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-05.png
# 820  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-21.png
# 821  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-01-23.png
# 822  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-09.png
# 823  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-02-05.png
# 824  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-01-15.png
# 825  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-01-02-03.png
# 826  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-07.png
# 827  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-01.png
# 828  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-23.png
# 829  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-01-02-13.png
# 830  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-02-21.png
# 831  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-17.png
# 832  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-01-02-01-05.png
# 833  /var/scratch/mpa326/ravdess_melspec_new/03-01-07-02-02-01-01.png
# 834  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-04.png
# 835  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-02.png
# 836  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-20.png
# 837  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-14.png
# 838  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-16.png
# 839  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-14.png
# 840  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-18.png
# 841  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-02.png
# 842  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-04.png
# 843  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-12.png
# 844  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-06.png
# 845  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-08.png
# 846  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-10.png
# 847  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-10.png
# 848  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-24.png
# 849  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-20.png
# 850  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-20.png
# 851  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-20.png
# 852  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-06.png
# 853  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-18.png
# 854  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-10.png
# 855  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-24.png
# 856  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-08.png
# 857  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-14.png
# 858  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-06.png
# 859  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-12.png
# 860  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-02.png
# 861  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-02.png
# 862  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-18.png
# 863  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-08.png
# 864  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-22.png
# 865  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-06.png
# 866  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-16.png
# 867  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-04.png
# 868  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-14.png
# 869  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-20.png
# 870  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-08.png
# 871  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-14.png
# 872  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-18.png
# 873  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-18.png
# 874  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-20.png
# 875  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-22.png
# 876  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-24.png
# 877  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-06.png
# 878  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-10.png
# 879  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-04.png
# 880  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-12.png
# 881  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-22.png
# 882  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-12.png
# 883  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-24.png
# 884  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-02.png
# 885  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-10.png
# 886  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-18.png
# 887  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-04.png
# 888  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-16.png
# 889  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-10.png
# 890  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-18.png
# 891  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-22.png
# 892  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-18.png
# 893  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-20.png
# 894  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-08.png
# 895  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-24.png
# 896  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-06.png
# 897  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-05.png
# 898  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-23.png
# 899  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-23.png
# 900  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-17.png
# 901  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-03.png
# 902  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-23.png
# 903  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-15.png
# 904  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-01.png
# 905  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-09.png
# 906  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-03.png
# 907  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-23.png
# 908  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-11.png
# 909  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-11.png
# 910  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-05.png
# 911  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-13.png
# 912  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-15.png
# 913  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-05.png
# 914  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-13.png
# 915  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-21.png
# 916  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-11.png
# 917  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-17.png
# 918  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-07.png
# 919  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-11.png
# 920  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-01.png
# 921  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-09.png
# 922  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-05.png
# 923  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-05.png
# 924  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-19.png
# 925  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-19.png
# 926  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-09.png
# 927  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-03.png
# 928  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-01.png
# 929  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-01.png
# 930  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-03.png
# 931  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-03.png
# 932  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-01.png
# 933  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-07.png
# 934  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-15.png
# 935  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-23.png
# 936  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-19.png
# 937  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-17.png
# 938  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-21.png
# 939  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-07.png
# 940  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-21.png
# 941  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-09.png
# 942  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-01.png
# 943  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-01-15.png
# 944  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-05.png
# 945  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-19.png
# 946  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-13.png
# 947  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-15.png
# 948  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-09.png
# 949  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-01-07.png
# 950  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-13.png
# 951  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-01-02-03.png
# 952  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-23.png
# 953  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-02-21.png
# 954  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-02-05.png
# 955  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-11.png
# 956  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-02-01-07.png
# 957  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-01-01-01-17.png
# 958  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-05.png
# 959  /var/scratch/mpa326/ravdess_melspec_new/03-01-08-02-02-02-07.png

# %%
labels = []
path_mels = []
genders = []
folder='/var/scratch/mpa326/ravdess_melspec_new/'
for class_index, class_name in enumerate(emotions_en):
            
            # Display the name of the class whose data is being extracted.
            print(f'Extracting Data of Class: {class_name}')
            
            # Get the list of video files present in the specific class name directory.
            files_list = list(train_df.melspec_path[train_df.emotion == class_name])
            
            # Iterate through all the files present in the files list.
            for video_file_path in files_list:
              y, sr = load_spec(video_file_path,1)
              fig = plt.Figure()
              canvas = FigureCanvas(fig)
              ax = fig.add_subplot(111)
              ax.set_axis_off()
              p = librosa.display.specshow(librosa.power_to_db(y), ax=ax)
              path=video_file_path.split('/')[-1].split('.')[0]
              fig.savefig(folder+path+'.png',bbox_inches='tight',pad_inches=0.0)
              labels.append(class_index)
              genders.append(df_audio.gender[df_audio.Audio_file == video_file_path].values[0])
              path_mels.append(folder+path+'.png')
# Out:
# Extracting Data of Class: neutral
# Extracting Data of Class: calm
# Extracting Data of Class: happy
# Extracting Data of Class: sad
# Extracting Data of Class: angry
# Extracting Data of Class: fearful
# Extracting Data of Class: disgust
# Extracting Data of Class: surprised

# %%
print(path_mels)
# Out:
# ['/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-01.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-01.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-01.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-01.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-02.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-02.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-02.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-02.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-03.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-03.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-03.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-03.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-04.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-04.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-04.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-04.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-05.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-05.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-05.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-05.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-06.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-06.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-06.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-06.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-07.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-07.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-07.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-07.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-08.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-08.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-08.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-08.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-09.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-09.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-09.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-09.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-10.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-10.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-10.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-10.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-11.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-11.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-11.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-11.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-12.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-12.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-12.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-12.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-13.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-13.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-13.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-13.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-14.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-14.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-01-14.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02-02-14.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-01-15.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-01-02-15.png', '/var/scratch/mpa326/ravdess_melspec_new/03-01-01-01-02 ...

# %%
import glob
path_mels=glob.glob(folder+"*.png")

# %%
train_df['emotion'] = pd.Categorical(train_df['emotion'], categories=emotions_en, ordered=True)

# Sort the DataFrame based on the 'emotions' column
train_df = train_df.sort_values(by='emotion')

# %%
val_df['emotion'] = pd.Categorical(val_df['emotion'], categories=emotions_en, ordered=True)

# Sort the DataFrame based on the 'emotions' column
val_df = val_df.sort_values(by='emotion')

# %%
test_df['emotion'] = pd.Categorical(test_df['emotion'], categories=emotions_en, ordered=True)

# Sort the DataFrame based on the 'emotions' column
test_df = test_df.sort_values(by='emotion')

# %%
train_paths = train_df['melspec_path']  # Replace 'data' with the actual column name for paths if different
train_genders = train_df['gender']
train_emotions = train_df['emotion']

# Extract paths, gender, and emotion labels from validation set
val_paths = val_df['melspec_path']  # Replace 'data' with the actual column name for paths if different
val_genders = val_df['gender']
val_emotions = val_df['emotion']

# Extract paths, gender, and emotion labels from test set
test_paths = test_df['melspec_path']  # Replace 'data' with the actual column name for paths if different
test_genders = test_df['gender']
test_emotions = test_df['emotion']

# %%
train_df
# Out:
#     codec_name  gender    emotion  width  height avg_frame_rate  \
# 535       h264  female    neutral   1280     720     30000/1001
# 924       h264  female    neutral   1280     720     30000/1001
# 480       h264  female    neutral   1280     720     30000/1001
# 567       h264  female    neutral   1280     720     30000/1001
# 776       h264  female    neutral   1280     720     30000/1001
# ..         ...     ...        ...    ...     ...            ...
# 806       h264    male  surprised   1280     720     30000/1001
# 812       h264  female  surprised   1280     720     30000/1001
# 823       h264    male  surprised   1280     720     30000/1001
# 186       h264  female  surprised   1280     720     30000/1001
# 503       h264  female  surprised   1280     720     30000/1001
#
#     display_aspect_ratio  nb_frames  duration  fps  \
# 535                16:09        109  3.636967   29
# 924                16:09        106  3.536867   29
# 480                16:09        103  3.436767   29
# 567                16:09        106  3.536867   29
# 776                16:09        107  3.570233   29
# ..                   ...        ...       ...  ...
# 806                16:09        102  3.403400   29
# 812                16:09        109  3.636967   29
# 823                16:09         92  3.069733   29
# 186                16:09         97  3.236567   29
# 503                16:09        104  3.470133   29
#
#                                                    dir  \
# 535  /var/scratch/mpa326/Ravdess_dataset/Audio_Spee...
# 924  /var/scratch/mpa326/Ravdess_dataset/Audio_Spee...
# 480  /var/scratch/mpa326/Ravdess_dataset/Audio_Spee...
# 567  /var/scratch/mpa326/Ravdess_dataset/Audio_Spee...
# 776  /var/scratch/mpa326/Ravdess_dataset/Audio_Spee...
# ..                                                 ...
# 806  /var/scratch/mpa326/Ravdess_dataset/Audio_Spee...
# 812  /var/scratch/mpa326/Ravdess_dataset/Audio_Spee...
# 823  /var/scratch/mpa326/Ravdess_dataset/Audio_Spee...
# 186  /var/scratch/mpa326/Ravdess_dataset/Audio_Spee...
# 503  /var/scratch/mpa326/Ravdess_dataset/Audio_Spee...
#
#                                           melspec_path
# 535  /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 924  /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 480  /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 567  /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 776  /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# ..                                                 ...
# 806  /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 812  /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 823  /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 186  /var/scratch/mpa326/ravdess_melspec_new/03-01-...
# 503  /var/scratch/mpa326/ravdess_melspec_new/03-01-...
#
# [1008 rows x 12 columns]

# %%
train_df = pd.read_csv('paths_train_audio.csv')
val_df = pd.read_csv('paths_val_audio.csv')
test_df = pd.read_csv('paths_test_audio.csv')

# %%
train_paths_aud_50m_50f = X_train_aud_50m_50f['melspec_path']
train_paths_aud_40m_60f = X_train_aud_40m_60f['melspec_path']
train_paths_aud_60m_40f = X_train_aud_60m_40f['melspec_path']
test_paths_aud = X_test_aud['melspec_path']

# %%
df_train_aud_50m_50f=np.ones((960, 128, 128, 3),dtype='uint8')
df_train_aud_40m_60f=np.ones((960, 128, 128, 3),dtype='uint8')
df_train_aud_60m_40f=np.ones((960, 128, 128, 3),dtype='uint8')
df_test = np.ones((288, 128, 128, 3), dtype='uint8')
for i in range(960):
  img=cv2.imread(train_paths_aud_50m_50f[i])
  img=cv2.resize(img,(128, 128))
  df_train_aud_50m_50f[i]=img

for i in range(960):
  img=cv2.imread(train_paths_aud_40m_60f[i])
  img=cv2.resize(img,(128, 128))
  df_train_aud_40m_60f[i]=img

for i in range(960):
  img=cv2.imread(train_paths_aud_60m_40f[i])
  img=cv2.resize(img,(128, 128))
  df_train_aud_60m_40f[i]=img


for i in range(288):
    img=cv2.imread(test_paths_aud[i])
    img=cv2.resize(img,(128,128))
    df_test[i] = img

# %%
df1 = {'features':df_train_aud_50m_50f}
df2 = {'features':df_train_aud_40m_60f}
df3 = {'features':df_train_aud_60m_40f}
df4 = {'features':df_test}

# %%
datafile = open('audio_train_50m_50f', 'ab')
pickle.dump(df1, datafile)                     
datafile.close()

# %%
datafile = open('audio_train_40m_60f', 'ab')
pickle.dump(df2, datafile)                     
datafile.close()

# %%
datafile = open('audio_train_60m_40f', 'ab')
pickle.dump(df3, datafile)                     
datafile.close()

# %%
datafile = open('audio_test_common', 'ab')
pickle.dump(df4, datafile)                     
datafile.close()
